# %%
# %load_ext autoreload
# %autoreload 2

import genanki
import webscrape as ws
import anki_utils as au
import numpy as np

import constants
import dill as pickle

# %%
import requests
import bs4
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm

# %%
def exclude_items(items, exclude_items):
    """"""
    
    return [item for item in items if not any(e_i in item for e_i in exclude_items)]

# %%
exclude_items(tags, ["Summaries"])
# Out:
# ['Emergency Medicine', 'Intensive Care Medicine']

# %%
SUMMARIES_LIST_GENERAL_URL = "https://www.thebottomline.org.uk/category/summaries/page/{page_number}/"

# %%
def get_summary_urls(summaries_list_general_url):
    """"""

    all_summaries = []
    for page_index in tqdm(range(1, 50)):
        summary_list_page_url = summaries_list_general_url.format(page_number=page_index)
        response = requests.get(summary_list_page_url)
        if response.status_code != 200:
            break
        page_soup = BeautifulSoup(response.text, 'html.parser')
        page_summaries = page_soup.find_all("h2", class_="entry-title post-title")
        all_summaries += [summary.find("a").attrs["href"] for summary in page_summaries]
    
    return all_summaries

# %%
summary_urls = get_summary_urls(SUMMARIES_LIST_GENERAL_URL)
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]

# %%
class Trial:
    def __init__(self, url):
        """"""
        self.url = url
        self.soup = BeautifulSoup(requests.get(url).text, 'html.parser')

# %%
trials = [Trial(summary_url) for summary_url in tqdm(summary_urls)]
# Out:
#   0%|          | 0/451 [00:00<?, ?it/s]

# %%
trial = trials[0]

# %%
def get_tags(summary_soup):
    """"""
    tag_items = summary_soup.find(class_="meta-category").find_all("a")
    tags = [tag_item.contents[0] for tag_item in tag_items]
    return exclude_items(tags, ["Summaries"])

get_tags(trial.soup)
# Out:
# ['Emergency Medicine', 'Intensive Care Medicine']

# %%
def get_trial_year(summary_soup):
    """"""
    for part in summary_soup.find_all("p"):
        line = part.text.lower()
        if "doi" in line:
            try:
                return int("".join(char for char in line.split("doi")[0] if char.isdigit()))
            except:
                return None
            break

# %%
for trial in tqdm(trials):
    get_trial_year(trial.soup)
# Out:
#   0%|          | 0/451 [00:00<?, ?it/s]

# %%
trial.soup.find_all("h3")[0]

# %%
trial.soup.find_all("h3")[0].span
# Out:
# <span style="font-size: large; font-weight: bold;">Clinical Question</span>

# %%
titles = []

for summary in tqdm(summaries):
    response = requests.get(summary.find("a").attrs["href"])
    summary_soup = BeautifulSoup(response.text, 'html.parser')
    title = summary_soup.find("h1")
    titles.append(title)
# Out:
#   0%|          | 0/451 [00:00<?, ?it/s]

# %%
CUSTOM_TRIAL_NAMES = ["CandiSep", "PreVent", "TracMan", "PlasmAr", "Pandemic Triage", "Reconnect"]

CUSTOM_TRIAL_NAME_MAP = {
    "Acetazolamide in Acute Decompensated Heart Failure with Volume Overload": "ADVOR",
    "Platelet Transfusion before CVC Placement in Patients with Thrombocytopenia": "PACER",
    "Emergency Department Resuscitative Endovascular Balloon Occlusion of the Aorta in Trauma Patients With Exsanguinating Hemorrhage": "UK-REBOA",
    "Aggressive or Moderate Fluid Resuscitation in Acute Pancreatitis": "WATERFALL",
    "Early and Empirical High-Dose Cryoprecipitate for Hemorrhage After Traumatic Injury": "CRYOSTAT-2"
}

def get_trial_name(title):
    """"""
    count = sum([c.isupper() for c in title])
    length = len(title)
    mean = count / length
    
    if mean >= 0.3 and length > 3:
        return title
    
    if "trial" in title:
        return title.split(" trial")[0]
    
    if "Trial" in title:
        return title.split(" Trial")[0]
    
    if "(" in title:
        return title
    
    if count >= 3 and length < 60:
        return title
    
    if ":" in title:
        return title.split(":")[0]
    
    if "–" in title:
        return title.split("–")[0]
    
    if any(c.isdigit() for c in title):
        return title
    
    if title in CUSTOM_TRIAL_NAMES:
        return title
    
    if title in CUSTOM_TRIAL_NAME_MAP:
        return CUSTOM_TRIAL_NAME_MAP[title]
    
    if length > 60:
        return title

    return False

# %%
clean_titles = []
failed_titles = []

for title in titles:
    title_clean = get_trial_name(title.text)
    if title_clean:
        clean_titles.append(title_clean)
    else:
        count = np.sum([c.isupper() for c in title.text])
        mean = count / len(title.text)
        failed_titles.append(f"{count} {len(title.text)} " + title.text)
        
        if title.text in CUSTOM_TRIAL_NAME_MAP:
            print(title.text, count, len(title.text))

# %%
sorted(failed_titles)[::-1]
# Out:
# ['2 8 McCardle',
#  '2 8 El Adawi',
#  '2 8 De Jonge',
#  '2 7 Xian Su',
#  '2 7 McCourt',
#  '2 3 SoM',
#  '2 17 Kleine-Brueggeney',
#  '2 16 Garrouste-Orgeas',
#  '2 14 Kentish-Barnes',
#  '2 14 Erythro-Emerge',
#  '2 13 Lars Anderson',
#  '1 9 Nishikimi',
#  '1 9 Hernández',
#  '1 9 Determann',
#  '1 9 Choudhury',
#  '1 8 Weingart',
#  '1 8 Kacmarek',
#  '1 8 Hagihara',
#  '1 8 Franklin',
#  '1 8 Bradford',
#  '1 8 Boulware',
#  '1 8 Bouderka',
#  '1 8 Anderson',
#  '1 7 Zochios',
#  '1 7 Ventura',
#  '1 7 Skrobik',
#  '1 7 Sjöblom',
#  '1 7 Seymour',
#  '1 7 Sessler',
#  '1 7 Sellick',
#  '1 7 Pivetta',
#  '1 7 Philpot',
#  '1 7 Pascall',
#  '1 7 Niemann',
#  '1 7 Morelli',
#  '1 7 Meacock',
#  '1 7 Maltese',
#  '1 7 Loubani',
#  '1 7 Heyland',
#  '1 7 Ferrari',
#  '1 7 Demoule',
#  '1 7 Bickell',
#  '1 7 Bellomo',
#  '1 6 Yeatts',
#  '1 6 Woolum',
#  '1 6 Vollam',
#  '1 6 Uranga',
#  '1 6 Torres',
#  '1 6 Suzuki',
#  '1 6 Subira',
#  '1 6 Stockl',
#  '1 6 Simons',
#  '1 6 Sadfar',
#  '1 6 Rivers',
#  '1 6 Riskin',
#  '1 6 Morris',
#  '1 6 Monnet',
#  '1 6 Meduri',
#  '1 6 Meduri',
#  '1 6 Mahler',
#  '1 6 Jacobs',
#  '1 6 Gujjar',
#  '1 6 Grissa',
#  '1 6 Foulds',
#  '1 6 Ferrie',
#  '1 6 Ferrer',
#  '1 6 Driver',
#  '1 6 Detsky',
#  '1 6 Davies',
#  '1 6 Bouwes',
#  '1 6 Annane',
#  '1 5 Young',
#  '1 5 Wahab',
#  '1 5 Talan',
#  '1 5 Strom',
#  '1 5 Simon',
#  '1 5 Patel',
#  '1 5 Motov',
#  '1 5 Marik',
#  '1 5 Lilja',
#  '1 5 Kumar',
#  '1 5 Kumar',
#  '1 5 Kress',
#  '1 4 Wang',
#  '1 4 Than',
#  '1 4 Sakr',
#  '1 4 Lyon',
#  '1 4 Hung',
#  '1 4 Doig',
#  '1 4 Corl',
#  '1 4 Atan',
#  '1 3 Sun',
#  '1 3 Liu',
#  '1 3 Koo',
#  '1 2 Gu',
#  '1 12 van Lieshout',
#  '1 12 Ramachandran',
#  '1 11 Olasveengen',
#  '1 11 Arulkumaran',
#  '1 10 Villanueva',
#  '1 10 Freemantle',
#  '1 10 Drakulovic',
#  '1 10 Chatterjee']

# %%
len(clean_titles)
# Out:
# 348

# %%
titles
# Out:
# [<h1 class="entry-title post-title">DanGer Shock – Microaxial Flow Pump in Infarct-Related Cardiogenic Shock</h1>,
#  <h1 class="entry-title post-title">NICO – Noninvasive Airway Management of Comatose Patients with Acute Poisoning</h1>,
#  <h1 class="entry-title post-title">Validation of the MIRACLE 2 Score for Prognostication After OOHCA</h1>,
#  <h1 class="entry-title post-title">ARiE Trial – Rifaximin for encephalopathy</h1>,
#  <h1 class="entry-title post-title">PROPHY-VAP: Ceftriaxone to prevent early ventilator-associated pneumonia</h1>,
#  <h1 class="entry-title post-title">EARLYDRAIN – Lumbar Cerebrospinal Fluid Drain Among Patients With aSAH</h1>,
#  <h1 class="entry-title post-title">ACORN</h1>,
#  <h1 class="entry-title post-title">STRESS-L: Landiolol and Organ Failure in Patients With Septic Shock</h1>,
#  <h1 class="entry-title post-title">Emergency Department Resuscitative Endovascular Balloon Occlusion of the Aorta in Trauma Patients With Exsanguinating Hemorrhage</h1>,
#  <h1 class="entry-title post-title">Early and Empirical High-Dose Cryoprecipitate for Hemorrhage After Traumatic Injury</h1>,
#  <h1 class="entry-title post-title">Acetazolamide in Acute Decompensated Heart Failure with Volume Overload</h1>,
#  <h1 class="entry-title post-title">Platelet Transfusion before CVC Placement in Patients with Thrombocytopenia</h1>,
#  <h1 class="entry-title post-title">DEVICE</h1>,
#  <h1 class="entry-title post-title">TAME</h1>,
#  <h1 class="entry-title post-title">PATCH</h1>,
#  <h1 class="entry-title post-title">AID-ICU</h1>,
#  <h1 class="entry-title post-title">CAPE COD</h1>,
#  <h1 class="entry-title post-title">INCEPTION</h1>,
#  <h1 class="entry-title post-title">EFFORT</h1>,
#  <h1 class="entry-title post-title">ECMO-CS</h1>,
#  <h1 class="entry-title post-title">EFFORT</h1>,
#  <h1 class="entry-title post-title">ECMO-CS</h1>,
#  <h1 class="entry-title post-title">CLOVERS</h1>,
#  <h1 class="entry-title post-title">PREPARE II</h1>,
#  <h1 class="entry-title post-title">Pro-MEDIC</h1>,
#  <h1 class="entry-title post-title">TEAM</h1>,
#  <h1 class="entry-title post-title">PILOT</h1>,
#  <h1 class="entry-title post-title">TBL Mini: Rib Fixation</h1>,
#  <h1 class="entry-title post-title">SuDDICU</h1>,
#  <h1 class="entry-title post-title">DOSEVF</h1>,
#  <h1 class="entry-title post-title">BOX (Oxygen)</h1>,
#  <h1 class="entry-title post-title">BOX Trial: Blood Pressure</h1>,
#  <h1 class="entry-title post-title">Aggressive or Moderate Fluid Resuscitation in Acute Pancreatitis</h1>,
#  <h1 class="entry-title post-title">LOVIT Trial</h1>,
#  <h1 class="entry-title post-title">CandiSep</h1>,
#  <h1 class="entry-title post-title">Supplemental Parental Nutrition and Abdominal Surgery</h1>,
#  <h1 class="entry-title post-title">Ferrari</h1>,
#  <h1 class="entry-title post-title">Classic Trial</h1>,
#  <h1 class="entry-title post-title">HYPO-ECMO</h1>,
#  <h1 class="entry-title post-title">FAKT</h1>,
#  <h1 class="entry-title post-title">SETPOINT2</h1>,
#  <h1 class="entry-title post-title">Endovascular Therapy for Large Ischemic Stroke</h1>,
#  <h1 class="entry-title post-title">SHINE</h1>,
#  <h1 class="entry-title post-title">DECRA</h1>,
#  <h1 class="entry-title post-title">RePHILL</h1>,
#  <h1 class="entry-title post-title">Prague OHCA</h1>,
#  <h1 class="entry-title post-title">TELSTAR</h1>,
#  <h1 class="entry-title post-title">COSMIC-EOL</h1>,
#  <h1 class="entry-title post-title">Terminal QRS distortion</h1>,
#  <h1 class="entry-title post-title">Emergency Medicine Evidence Updates – January 2022</h1>,
#  <h1 class="entry-title post-title">PALACS</h1>,
#  <h1 class="entry-title post-title">CONTROLING</h1>,
#  <h1 class="entry-title post-title">COMBAT-COVID</h1>,
#  <h1 class="entry-title post-title">COCA</h1>,
#  <h1 class="entry-title post-title">SILENCE</h1>,
#  <h1 class="entry-title post-title">SNOCAT</h1>,
#  <h1 class="entry-title post-title">VAM-IHCA</h1>,
#  <h1 class="entry-title post-title">COAST</h1>,
#  <h1 class="entry-title post-title">COVERT MI</h1>,
#  <h1 class="entry-title post-title">RECOVERY REGEN-COV</h1>,
#  <h1 class="entry-title post-title">COVERT MI</h1>,
#  <h1 class="entry-title post-title">RECOVERY REGEN-COV</h1>,
#  <h1 class="entry-title post-title">The REST Trial</h1>,
#  <h1 class="entry-title post-title">COVID STEROID 2</h1>,
#  <h1 class="entry-title post-title">COV-BARRIER</h1>,
#  <h1 class="entry-title post-title">TOMAHAWK</h1>,
#  <h1 class="entry-title post-title">DOREMI</h1>,
#  <h1 class="entry-title post-title">RECOVERY-RS</h1>,
#  <h1 class="entry-title post-title">BaSICS</h1>,
#  <h1 class="entry-title post-title">McCardle</h1>,
#  <h1 class="entry-title post-title">COBI</h1>,
#  <h1 class="entry-title post-title">TTM2</h1>,
#  <h1 class="entry-title post-title">STYLETO</h1>,
#  <h1 class="entry-title post-title">TRAAP2</h1>,
#  <h1 class="entry-title post-title">MENDS2</h1>,
#  <h1 class="entry-title post-title">Sjöblom</h1>,
#  <h1 class="entry-title post-title">ULTRA</h1>,
#  <h1 class="entry-title post-title">DEXA-ARDS</h1>,
#  <h1 class="entry-title post-title">FEISTY</h1>,
#  <h1 class="entry-title post-title">Young</h1>,
#  <h1 class="entry-title post-title">CERTA</h1>,
#  <h1 class="entry-title post-title">SHIPMAN</h1>,
#  <h1 class="entry-title post-title">CHARLI</h1>,
#  <h1 class="entry-title post-title">REALITY</h1>,
#  <h1 class="entry-title post-title">HOT-ICU</h1>,
#  <h1 class="entry-title post-title">TOCIBRAS</h1>,
#  <h1 class="entry-title post-title">Dex-CSDH</h1>,
#  <h1 class="entry-title post-title">PlasmAr</h1>,
#  <h1 class="entry-title post-title">REMAP-CAP IL-6</h1>,
#  <h1 class="entry-title post-title">BACC</h1>,
#  <h1 class="entry-title post-title">DANMASK-19</h1>,
#  <h1 class="entry-title post-title">ARREST</h1>,
#  <h1 class="entry-title post-title">RECOVERY: COVID-19 Kaletra</h1>,
#  <h1 class="entry-title post-title">ITACTIC</h1>,
#  <h1 class="entry-title post-title">REDECAP</h1>,
#  <h1 class="entry-title post-title">MIDAS</h1>,
#  <h1 class="entry-title post-title">ATESS</h1>,
#  <h1 class="entry-title post-title">REMAP-CAP</h1>,
#  <h1 class="entry-title post-title">LOCO2</h1>,
#  <h1 class="entry-title post-title">Timing of Endoscopy for Acute Upper Gastrointestinal Bleeding</h1>,
#  <h1 class="entry-title post-title">Propanalol in severe TBI</h1>,
#  <h1 class="entry-title post-title">PRIMARY SPONTANEOUS PNEUMOTHORAX (PSP) TRIAL</h1>,
#  <h1 class="entry-title post-title">GRECCO-19</h1>,
#  <h1 class="entry-title post-title">STARRT-AKI</h1>,
#  <h1 class="entry-title post-title">RECOVERY: COVID-19 dexamethasone</h1>,
#  <h1 class="entry-title post-title">HALT-IT</h1>,
#  <h1 class="entry-title post-title">DIRECT-MT</h1>,
#  <h1 class="entry-title post-title">Boulware</h1>,
#  <h1 class="entry-title post-title">VIOLET</h1>,
#  <h1 class="entry-title post-title">ACTT-1</h1>,
#  <h1 class="entry-title post-title">Hung</h1>,
#  <h1 class="entry-title post-title">Wang</h1>,
#  <h1 class="entry-title post-title">LOTUS China</h1>,
#  <h1 class="entry-title post-title">Pandemic Triage</h1>,
#  <h1 class="entry-title post-title">FABLED</h1>,
#  <h1 class="entry-title post-title">CURASMUR</h1>,
#  <h1 class="entry-title post-title">NONSEDA</h1>,
#  <h1 class="entry-title post-title">65 Trial</h1>,
#  <h1 class="entry-title post-title">PEPTIC</h1>,
#  <h1 class="entry-title post-title">VITAMINS</h1>,
#  <h1 class="entry-title post-title">ESETT</h1>,
#  <h1 class="entry-title post-title">PEG-eD</h1>,
#  <h1 class="entry-title post-title">LEAP2</h1>,
#  <h1 class="entry-title post-title">ANTHARTIC</h1>,
#  <h1 class="entry-title post-title">Sessler</h1>,
#  <h1 class="entry-title post-title">COLCOT</h1>,
#  <h1 class="entry-title post-title">BALANCE</h1>,
#  <h1 class="entry-title post-title">CRASH-3</h1>,
#  <h1 class="entry-title post-title">ICU-ROX</h1>,
#  <h1 class="entry-title post-title">Vitamin C Sepsis</h1>,
#  <h1 class="entry-title post-title">Subira</h1>,
#  <h1 class="entry-title post-title">HYPERION</h1>,
#  <h1 class="entry-title post-title">Garrouste-Orgeas</h1>,
#  <h1 class="entry-title post-title">SoM</h1>,
#  <h1 class="entry-title post-title">PHARLAP</h1>,
#  <h1 class="entry-title post-title">PAUSE</h1>,
#  <h1 class="entry-title post-title">AVERT Shock</h1>,
#  <h1 class="entry-title post-title">Zochios</h1>,
#  <h1 class="entry-title post-title">TRACT Transfusion Volume</h1>,
#  <h1 class="entry-title post-title">TRACT Tranfusion Timing</h1>,
#  <h1 class="entry-title post-title">DRAIN</h1>,
#  <h1 class="entry-title post-title">PROBESE</h1>,
#  <h1 class="entry-title post-title">Simon</h1>,
#  <h1 class="entry-title post-title">AVB-TIPS</h1>,
#  <h1 class="entry-title post-title">IVC Filters</h1>,
#  <h1 class="entry-title post-title">OPTALYSE PE</h1>,
#  <h1 class="entry-title post-title">ROSE</h1>,
#  <h1 class="entry-title post-title">REDUCE Haloperidol</h1>,
#  <h1 class="entry-title post-title">SCARLET</h1>,
#  <h1 class="entry-title post-title">EPVent2</h1>,
#  <h1 class="entry-title post-title">EXTEND</h1>,
#  <h1 class="entry-title post-title">SPICE III</h1>,
#  <h1 class="entry-title post-title">PreVent</h1>,
#  <h1 class="entry-title post-title">MAPAS</h1>,
#  <h1 class="entry-title post-title">SHoC-ED 3</h1>,
#  <h1 class="entry-title post-title">Woolum</h1>,
#  <h1 class="entry-title post-title">EVALD</h1>,
#  <h1 class="entry-title post-title">ICON</h1>,
#  <h1 class="entry-title post-title">COACT</h1>,
#  <h1 class="entry-title post-title">MASTERS</h1>,
#  <h1 class="entry-title post-title">SUPERNOVA</h1>,
#  <h1 class="entry-title post-title">ANDROMEDA-SHOCK</h1>,
#  <h1 class="entry-title post-title">TICH-2</h1>,
#  <h1 class="entry-title post-title">PREVENT</h1>,
#  <h1 class="entry-title post-title">iPROVE</h1>,
#  <h1 class="entry-title post-title">CENSER</h1>,
#  <h1 class="entry-title post-title">Pivetta</h1>,
#  <h1 class="entry-title post-title">The IRIS Cricoid Trial</h1>,
#  <h1 class="entry-title post-title">HERCULES</h1>,
#  <h1 class="entry-title post-title">RACE</h1>,
#  <h1 class="entry-title post-title">TARGET</h1>,
#  <h1 class="entry-title post-title">Don’t forget the LEGO</h1>,
#  <h1 class="entry-title post-title">BREATHE</h1>,
#  <h1 class="entry-title post-title">HIGH</h1>,
#  <h1 class="entry-title post-title">PReVENT</h1>,
#  <h1 class="entry-title post-title">MIND-USA</h1>,
#  <h1 class="entry-title post-title">SUP-ICU</h1>,
#  <h1 class="entry-title post-title">IDEAL-ICU</h1>,
#  <h1 class="entry-title post-title">POLAR</h1>,
#  <h1 class="entry-title post-title">EUPHRATES</h1>,
#  <h1 class="entry-title post-title">IMPACT</h1>,
#  <h1 class="entry-title post-title">PART</h1>,
#  <h1 class="entry-title post-title">TRICS-III 6 month follow up</h1>,
#  <h1 class="entry-title post-title">High STEACS</h1>,
#  <h1 class="entry-title post-title">Vollam</h1>,
#  <h1 class="entry-title post-title">FiSh</h1>,
#  <h1 class="entry-title post-title">AIRWAYS-2</h1>,
#  <h1 class="entry-title post-title">CULPRIT-SHOCK: One year follow up</h1>,
#  <h1 class="entry-title post-title">Atan</h1>,
#  <h1 class="entry-title post-title">PARTNER</h1>,
#  <h1 class="entry-title post-title">Riskin</h1>,
#  <h1 class="entry-title post-title">PAMPer</h1>,
#  <h1 class="entry-title post-title">PARAMEDIC2</h1>,
#  <h1 class="entry-title post-title">Liu</h1>,
#  <h1 class="entry-title post-title">Franklin</h1>,
#  <h1 class="entry-title post-title">6S</h1>,
#  <h1 class="entry-title post-title">SHoC-ED</h1>,
#  <h1 class="entry-title post-title">BICAR-ICU</h1>,
#  <h1 class="entry-title post-title">IOTA</h1>,
#  <h1 class="entry-title post-title">EXTEND IA TNK</h1>,
#  <h1 class="entry-title post-title">EOLIA</h1>,
#  <h1 class="entry-title post-title">CASS</h1>,
#  <h1 class="entry-title post-title">RELIEF</h1>,
#  <h1 class="entry-title post-title">DAWN</h1>,
#  <h1 class="entry-title post-title">Stockl</h1>,
#  <h1 class="entry-title post-title">FEDORA</h1>,
#  <h1 class="entry-title post-title">Gujjar</h1>,
#  <h1 class="entry-title post-title">Nishikimi</h1>,
#  <h1 class="entry-title post-title">Intensive Insulin Therapy</h1>,
#  <h1 class="entry-title post-title">DEFUSE 3</h1>,
#  <h1 class="entry-title post-title">Skrobik</h1>,
#  <h1 class="entry-title post-title">APROCCHSS</h1>,
#  <h1 class="entry-title post-title">EPaNIC</h1>,
#  <h1 class="entry-title post-title">SALT-ED</h1>,
#  <h1 class="entry-title post-title">SMART</h1>,
#  <h1 class="entry-title post-title">READS</h1>,
#  <h1 class="entry-title post-title">ELAIN FOLLOW-UP</h1>,
#  <h1 class="entry-title post-title">Arulkumaran</h1>,
#  <h1 class="entry-title post-title">LIPPSMAck-POP</h1>,
#  <h1 class="entry-title post-title">BILEVEL-APRV</h1>,
#  <h1 class="entry-title post-title">ADRENAL</h1>,
#  <h1 class="entry-title post-title">CURE</h1>,
#  <h1 class="entry-title post-title">COIITSS</h1>,
#  <h1 class="entry-title post-title">ART</h1>,
#  <h1 class="entry-title post-title">MoDUS</h1>,
#  <h1 class="entry-title post-title">PRESERVE</h1>,
#  <h1 class="entry-title post-title">TRICS-III</h1>,
#  <h1 class="entry-title post-title">SSSP2</h1>,
#  <h1 class="entry-title post-title">ICE-CUB 2</h1>,
#  <h1 class="entry-title post-title">CHECK-UP Position</h1>,
#  <h1 class="entry-title post-title">CHECK-UP Checklist</h1>,
#  <h1 class="entry-title post-title">EAT-ICU</h1>,
#  <h1 class="entry-title post-title">DREAMS</h1>,
#  <h1 class="entry-title post-title">Reconnect</h1>,
#  <h1 class="entry-title post-title">INPRESS</h1>,
#  <h1 class="entry-title post-title">TRANSFUSE</h1>,
#  <h1 class="entry-title post-title">ATACAS TXA</h1>,
#  <h1 class="entry-title post-title">ATACAS Asp</h1>,
#  <h1 class="entry-title post-title">DETO2X-AMI</h1>,
#  <h1 class="entry-title post-title">60/60 sign for Acute PE</h1>,
#  <h1 class="entry-title post-title">Seymour</h1>,
#  <h1 class="entry-title post-title">POISE 1</h1>,
#  <h1 class="entry-title post-title">SHENFU</h1>,
#  <h1 class="entry-title post-title">EPICC</h1>,
#  <h1 class="entry-title post-title">TTM 48</h1>,
#  <h1 class="entry-title post-title">SPARK</h1>,
#  <h1 class="entry-title post-title">Demoule</h1>,
#  <h1 class="entry-title post-title">Corl</h1>,
#  <h1 class="entry-title post-title">Hernandez 2</h1>,
#  <h1 class="entry-title post-title">Kentish-Barnes</h1>,
#  <h1 class="entry-title post-title">PRECISE</h1>,
#  <h1 class="entry-title post-title">REVIVE</h1>,
#  <h1 class="entry-title post-title">Detsky</h1>,
#  <h1 class="entry-title post-title">TRICOP</h1>,
#  <h1 class="entry-title post-title">ATHOS-3</h1>,
#  <h1 class="entry-title post-title">INSTINCT</h1>,
#  <h1 class="entry-title post-title">EMPIRICUS</h1>,
#  <h1 class="entry-title post-title">Lars Anderson</h1>,
#  <h1 class="entry-title post-title">WOMAN Trial</h1>,
#  <h1 class="entry-title post-title">DESIRE</h1>,
#  <h1 class="entry-title post-title">CHEETAH</h1>,
#  <h1 class="entry-title post-title">MACMAN</h1>,
#  <h1 class="entry-title post-title">LEVO-CTS</h1>,
#  <h1 class="entry-title post-title">NIVAS</h1>,
#  <h1 class="entry-title post-title">Choudhury</h1>,
#  <h1 class="entry-title post-title">AMACING</h1>,
#  <h1 class="entry-title post-title">OPERA</h1>,
#  <h1 class="entry-title post-title">IPHIVAP</h1>,
#  <h1 class="entry-title post-title">Simons</h1>,
#  <h1 class="entry-title post-title">El Adawi</h1>,
#  <h1 class="entry-title post-title">Ferrie</h1>,
#  <h1 class="entry-title post-title">Marik</h1>,
#  <h1 class="entry-title post-title">Talan</h1>,
#  <h1 class="entry-title post-title">Uranga</h1>,
#  <h1 class="entry-title post-title">HYBERNATUS</h1>,
#  <h1 class="entry-title post-title">Xian Su</h1>,
#  <h1 class="entry-title post-title">RENAL Trial</h1>,
#  <h1 class="entry-title post-title">IRONMAN</h1>,
#  <h1 class="entry-title post-title">Mahler</h1>,
#  <h1 class="entry-title post-title">POKER</h1>,
#  <h1 class="entry-title post-title">POCUS: Kristensen</h1>,
#  <h1 class="entry-title post-title">POCUS: Batllori</h1>,
#  <h1 class="entry-title post-title">POCUS: Feissel</h1>,
#  <h1 class="entry-title post-title">POCUS: Moretti</h1>,
#  <h1 class="entry-title post-title">POCUS: Lichtenstein</h1>,
#  <h1 class="entry-title post-title">Foulds</h1>,
#  <h1 class="entry-title post-title">Koo</h1>,
#  <h1 class="entry-title post-title">Patel</h1>,
#  <h1 class="entry-title post-title">OXYGEN-ICU</h1>,
#  <h1 class="entry-title post-title">HYPRESS</h1>,
#  <h1 class="entry-title post-title">LeoPARDS</h1>,
#  <h1 class="entry-title post-title">CLASSIC</h1>,
#  <h1 class="entry-title post-title">Grissa</h1>,
#  <h1 class="entry-title post-title">PATCH</h1>,
#  <h1 class="entry-title post-title">van Lieshout</h1>,
#  <h1 class="entry-title post-title">RESCUEicp</h1>,
#  <h1 class="entry-title post-title">Philpot</h1>,
#  <h1 class="entry-title post-title">Morris</h1>,
#  <h1 class="entry-title post-title">Subtle STEMI</h1>,
#  <h1 class="entry-title post-title">VASST</h1>,
#  <h1 class="entry-title post-title">VANISH Trial</h1>,
#  <h1 class="entry-title post-title">PROCAMIO</h1>,
#  <h1 class="entry-title post-title">HOT-ER</h1>,
#  <h1 class="entry-title post-title">ATACH-2 Trial</h1>,
#  <h1 class="entry-title post-title">REACT 2</h1>,
#  <h1 class="entry-title post-title">The Swedish Spinal Stenosis Study</h1>,
#  <h1 class="entry-title post-title">Erythro-Emerge</h1>,
#  <h1 class="entry-title post-title">ELAIN</h1>,
#  <h1 class="entry-title post-title">AKIKI</h1>,
#  <h1 class="entry-title post-title">Kleine-Brueggeney</h1>,
#  <h1 class="entry-title post-title">Anderson</h1>,
#  <h1 class="entry-title post-title">Meacock</h1>,
#  <h1 class="entry-title post-title">Drakulovic</h1>,
#  <h1 class="entry-title post-title">Monnet</h1>,
#  <h1 class="entry-title post-title">The Heparin Citrate Study</h1>,
#  <h1 class="entry-title post-title">The Refeeding Syndrome Trial</h1>,
#  <h1 class="entry-title post-title">After 80 study</h1>,
#  <h1 class="entry-title post-title">ALPS</h1>,
#  <h1 class="entry-title post-title">DahLIA</h1>,
#  <h1 class="entry-title post-title">Kacmarek</h1>,
#  <h1 class="entry-title post-title">Hernández</h1>,
#  <h1 class="entry-title post-title">TRACHUS</h1>,
#  <h1 class="entry-title post-title">Maltese</h1>,
#  <h1 class="entry-title post-title">Sakr</h1>,
#  <h1 class="entry-title post-title">DIABOLO</h1>,
#  <h1 class="entry-title post-title">STITCH (trauma)</h1>,
#  <h1 class="entry-title post-title">ANNEXA</h1>,
#  <h1 class="entry-title post-title">Wahab</h1>,
#  <h1 class="entry-title post-title">BLISS</h1>,
#  <h1 class="entry-title post-title">APPAC</h1>,
#  <h1 class="entry-title post-title">Ventura</h1>,
#  <h1 class="entry-title post-title">MULLET</h1>,
#  <h1 class="entry-title post-title">Eurotherm3235</h1>,
#  <h1 class="entry-title post-title">PRORATA</h1>,
#  <h1 class="entry-title post-title">ROC-CCC</h1>,
#  <h1 class="entry-title post-title">Heyland</h1>,
#  <h1 class="entry-title post-title">Bradford</h1>,
#  <h1 class="entry-title post-title">EPO-TBI</h1>,
#  <h1 class="entry-title post-title">3Sites</h1>,
#  <h1 class="entry-title post-title">Pascall</h1>,
#  <h1 class="entry-title post-title">FELLOW</h1>,
#  <h1 class="entry-title post-title">SPLIT</h1>,
#  <h1 class="entry-title post-title">HEAT</h1>,
#  <h1 class="entry-title post-title">BLING2</h1>,
#  <h1 class="entry-title post-title">AVOID</h1>,
#  <h1 class="entry-title post-title">Motov</h1>,
#  <h1 class="entry-title post-title">REVERT</h1>,
#  <h1 class="entry-title post-title">Idarucizumab for Dabigatran Reversal</h1>,
#  <h1 class="entry-title post-title">THAPCA-OH</h1>,
#  <h1 class="entry-title post-title">BRIDGE Study</h1>,
#  <h1 class="entry-title post-title">Niemann</h1>,
#  <h1 class="entry-title post-title">PermiT</h1>,
#  <h1 class="entry-title post-title">Freemantle</h1>,
#  <h1 class="entry-title post-title">STOP-IT</h1>,
#  <h1 class="entry-title post-title">ABLE</h1>,
#  <h1 class="entry-title post-title">SHOCK 2</h1>,
#  <h1 class="entry-title post-title">Suzuki</h1>,
#  <h1 class="entry-title post-title">Loubani</h1>,
#  <h1 class="entry-title post-title">BEST:TRIP</h1>,
#  <h1 class="entry-title post-title">FEAST</h1>,
#  <h1 class="entry-title post-title">EUSOS</h1>,
#  <h1 class="entry-title post-title">PYTHON</h1>,
#  <h1 class="entry-title post-title">DESTINY II</h1>,
#  <h1 class="entry-title post-title">FLORALI</h1>,
#  <h1 class="entry-title post-title">Lyon</h1>,
#  <h1 class="entry-title post-title">STOPAH</h1>,
#  <h1 class="entry-title post-title">Kumar</h1>,
#  <h1 class="entry-title post-title">PREOXYFLOW</h1>,
#  <h1 class="entry-title post-title">Gu</h1>,
#  <h1 class="entry-title post-title">Bouwes</h1>,
#  <h1 class="entry-title post-title">TITRe2</h1>,
#  <h1 class="entry-title post-title">Lilja</h1>,
#  <h1 class="entry-title post-title">Torres</h1>,
#  <h1 class="entry-title post-title">ProMISe</h1>,
#  <h1 class="entry-title post-title">Determann</h1>,
#  <h1 class="entry-title post-title">MOnIToR trial</h1>,
#  <h1 class="entry-title post-title">CRASH-2</h1>,
#  <h1 class="entry-title post-title">TRUST</h1>,
#  <h1 class="entry-title post-title">PROPPR</h1>,
#  <h1 class="entry-title post-title">RESTORE</h1>,
#  <h1 class="entry-title post-title">VITdAL-ICU</h1>,
#  <h1 class="entry-title post-title">ACURASYS</h1>,
#  <h1 class="entry-title post-title">CHEST</h1>,
#  <h1 class="entry-title post-title">CHEER</h1>,
#  <h1 class="entry-title post-title">Driver</h1>,
#  <h1 class="entry-title post-title">HARP2</h1>,
#  <h1 class="entry-title post-title">CALORIES</h1>,
#  <h1 class="entry-title post-title">ABC Trial</h1>,
#  <h1 class="entry-title post-title">Sun</h1>,
#  <h1 class="entry-title post-title">Morelli</h1>,
#  <h1 class="entry-title post-title">PROWESS-SHOCK</h1>,
#  <h1 class="entry-title post-title">Weingart</h1>,
#  <h1 class="entry-title post-title">Sellick</h1>,
#  <h1 class="entry-title post-title">Ramachandran</h1>,
#  <h1 class="entry-title post-title">KETASED</h1>,
#  <h1 class="entry-title post-title">Yeatts</h1>,
#  <h1 class="entry-title post-title">McCourt</h1>,
#  <h1 class="entry-title post-title">ARF Trial Network</h1>,
#  <h1 class="entry-title post-title">MIDEX-PRODEX</h1>,
#  <h1 class="entry-title post-title">TRISS</h1>,
#  <h1 class="entry-title post-title">ARISE</h1>,
#  <h1 class="entry-title post-title">Rivers</h1>,
#  <h1 class="entry-title post-title">Sadfar</h1>,
#  <h1 class="entry-title post-title">Bellomo</h1>,
#  <h1 class="entry-title post-title">Doig</h1>,
#  <h1 class="entry-title post-title">De Jonge</h1>,
#  <h1 class="entry-title post-title">HOPE-ICU</h1>,
#  <h1 class="entry-title post-title">PAC-MAN</h1>,
#  <h1 class="entry-title post-title">CRASH-1</h1>,
#  <h1 class="entry-title post-title">Meduri</h1>,
#  <h1 class="entry-title post-title">Annane</h1>,
#  <h1 class="entry-title post-title">REDUCE</h1>,
#  <h1 class="entry-title post-title">VSE</h1>,
#  <h1 class="entry-title post-title">TracMan</h1>,
#  <h1 class="entry-title post-title">Bouderka</h1>,
#  <h1 class="entry-title post-title">Ferrer</h1>,
#  <h1 class="entry-title post-title">Kumar</h1>,
#  <h1 class="entry-title post-title">3Mg trial</h1>,
#  <h1 class="entry-title post-title">Strom</h1>,
#  <h1 class="entry-title post-title">CATS</h1>,
#  <h1 class="entry-title post-title">CESAR</h1>,
#  <h1 class="entry-title post-title">Chatterjee</h1>,
#  <h1 class="entry-title post-title">TOPCOAT</h1>,
#  <h1 class="entry-title post-title">PEITHO</h1>,
#  <h1 class="entry-title post-title">MOPETT</h1>,
#  <h1 class="entry-title post-title">MAPPETT 3</h1>,
#  <h1 class="entry-title post-title">SEPSISPAM</h1>,
#  <h1 class="entry-title post-title">NICE-SUGAR</h1>,
#  <h1 class="entry-title post-title">CORTICUS</h1>,
#  <h1 class="entry-title post-title">Than</h1>,
#  <h1 class="entry-title post-title">OSCAR</h1>,
#  <h1 class="entry-title post-title">Jacobs</h1>,
#  <h1 class="entry-title post-title">OPTIMISE</h1>,
#  <h1 class="entry-title post-title">Villanueva</h1>,
#  <h1 class="entry-title post-title">Olasveengen</h1>,
#  <h1 class="entry-title post-title">Hagihara</h1>,
#  <h1 class="entry-title post-title">TRICC</h1>,
#  <h1 class="entry-title post-title">ARMA</h1>,
#  <h1 class="entry-title post-title">Kress</h1>,
#  <h1 class="entry-title post-title">PROSEVA</h1>,
#  <h1 class="entry-title post-title">SAFE Study</h1>,
#  <h1 class="entry-title post-title">MACS</h1>,
#  <h1 class="entry-title post-title">ALBIOS</h1>,
#  <h1 class="entry-title post-title">ProCESS</h1>,
#  <h1 class="entry-title post-title">TTM</h1>,
#  <h1 class="entry-title post-title">Davies</h1>,
#  <h1 class="entry-title post-title">SLEAP</h1>,
#  <h1 class="entry-title post-title">TICACOS</h1>,
#  <h1 class="entry-title post-title">Meduri</h1>,
#  <h1 class="entry-title post-title">HACA</h1>,
#  <h1 class="entry-title post-title">Bickell</h1>]

# %%
response = requests.get(self.url)
self.page_soup = BeautifulSoup(response.text, 'html.parser')
self.sections = [Section(section) for section in self.page_soup.find_all("span", class_="mw-headline")]
self.section_titles, new_sections = [], []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 response = requests.get(self.url)
#       2 self.page_soup = BeautifulSoup(response.text, 'html.parser')
#       3 self.sections = [Section(section) for section in self.page_soup.find_all("span", class_="mw-headline")]
#
# NameError: name 'requests' is not defined
